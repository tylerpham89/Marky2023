# %%
import pandas as pd

# Read the train CSV file
input_filename = 'train.csv'
df = pd.read_csv(input_filename)

# Extract the data catagories
font_data = df['font']
parameters_tone_data = df['parameters_tone']#add
parameters_switchboard_template_name_data = df['parameters_switchboard_template_name']
parameters_prompt_template_name_data = df['parameters_prompt_template_name']#add
parameters_photo_search_term_data = df['parameters_photo_search_term']


# Finds NaN in font and gives value 0 for NaN, otherwise 1
new_list_font = []
for i in font_data:
    if (pd.isna(i)):
        new_list_font.append(0)
    else:
        new_list_font.append(1)

df['font'] = new_list_font

# Finds NaN in parameters_tone and gives value 0 for NaN, otherwise 1
new_list_parameters_tone = []
for i in parameters_tone_data:
    if (pd.isna(i)):
        new_list_parameters_tone.append(0)
        count_nan += 1
    else:
        new_list_parameters_tone.append(1)
        count_other += 1
df['parameters_tone'] = new_list_parameters_tone

# Finds NaN in parameters_switchboard_template_name and gives value 0 for NaN, otherwise 1
new_list_parameters_switchboard_template_name = []
for i in parameters_switchboard_template_name_data:
    if (pd.isna(i)):
        new_list_parameters_switchboard_template_name.append(0)
    else:
        new_list_parameters_switchboard_template_name.append(1)

df['parameters_switchboard_template_name'] = new_list_parameters_switchboard_template_name

# Finds NaN in parameters_prompt_template_name and gives value 0 for NaN, otherwise 1
new_list_parameters_prompt_template_name = []
for i in parameters_prompt_template_name_data:
    if (pd.isna(i)):
        new_list_parameters_prompt_template_name.append(0)
    else:
        new_list_parameters_prompt_template_name.append(1)

df['parameters_prompt_template_name'] = new_list_parameters_prompt_template_name

# Finds NaN in parameters_photo_search_term and gives value 0 for NaN, otherwise 1
new_list_parameters_photo_search_term = []
for i in parameters_photo_search_term_data:
    if (pd.isna(i)):
        new_list_parameters_photo_search_term.append(0)
    else:
        new_list_parameters_photo_search_term.append(1)

df['parameters_photo_search_term'] = new_list_parameters_photo_search_term

#create new replica train file with updated information
df.to_csv('replicated_train.csv', index = False)

# Read the test CSV file
input_filename = 'test.csv'
df = pd.read_csv(input_filename)

# Extract the data catagories
font_data = df['font']
parameters_tone_data = df['parameters_tone']
parameters_switchboard_template_name_data = df['parameters_switchboard_template_name']
parameters_prompt_template_name_data = df['parameters_prompt_template_name']
parameters_photo_search_term_data = df['parameters_photo_search_term']


# Finds NaN in font and gives value 0 for NaN, otherwise 1
new_list_font = []
for i in font_data:
    if (pd.isna(i)):
        new_list_font.append(0)
    else:
        new_list_font.append(1)

df['font'] = new_list_font

# Finds NaN in parameters_tone and gives value 0 for NaN, otherwise 1
new_list_parameters_tone = []
for i in parameters_tone_data:
    if (pd.isna(i)):
        new_list_parameters_tone.append(0)
        count_nan += 1
    else:
        new_list_parameters_tone.append(1)
        count_other += 1
df['parameters_tone'] = new_list_parameters_tone

# Finds NaN in parameters_switchboard_template_name and gives value 0 for NaN, otherwise 1
new_list_parameters_switchboard_template_name = []
for i in parameters_switchboard_template_name_data:
    if (pd.isna(i)):
        new_list_parameters_switchboard_template_name.append(0)
    else:
        new_list_parameters_switchboard_template_name.append(1)

df['parameters_switchboard_template_name'] = new_list_parameters_switchboard_template_name

# Finds NaN in parameters_prompt_template_name and gives value 0 for NaN, otherwise 1
new_list_parameters_prompt_template_name = []
for i in parameters_prompt_template_name_data:
    if (pd.isna(i)):
        new_list_parameters_prompt_template_name.append(0)
    else:
        new_list_parameters_prompt_template_name.append(1)

df['parameters_prompt_template_name'] = new_list_parameters_prompt_template_name

# Finds NaN in parameters_photo_search_term and gives value 0 for NaN, otherwise 1
new_list_parameters_photo_search_term = []
for i in parameters_photo_search_term_data:
    if (pd.isna(i)):
        new_list_parameters_photo_search_term.append(0)
    else:
        new_list_parameters_photo_search_term.append(1)

df['parameters_photo_search_term'] = new_list_parameters_photo_search_term

#create new replica train file with updated information
df.to_csv('replicated_test.csv', index = False)
# Out:
#                                         id  user_edited  font  \
# 0     4877eee1-f059-4199-a73e-6e272d4a2516        False     0
# 1     01b17304-8074-4cc4-803d-52d1c04ad419        False     0
# 2     4834811e-115a-429d-9353-4a18752511c6        False     0
# 3     7ec3ca31-d2c3-4757-826a-687f657e1ea4        False     0
# 4     20021977-8388-4c41-8700-1f8dc5dcc470        False     0
# ...                                    ...          ...   ...
# 1640  2d8b3cd8-d32b-4e2a-8312-fa9027f44bc8        False     0
# 1641  39a9d3c3-aaad-482d-a1f5-2969c8fd33cf        False     0
# 1642  e4282292-122d-46fd-b1eb-3bcd363a32c8        False     0
# 1643  dcda99f5-6743-4cd7-b81c-51d95c539080        False     0
# 1644  62709ff0-96b1-46a2-8c01-bc2d57891ee7        False     0
#
#                                                   image  \
# 0     https://marky-image-posts.s3.us-east-2.amazona...
# 1     https://marky-image-posts.s3.amazonaws.com/7f8...
# ...
